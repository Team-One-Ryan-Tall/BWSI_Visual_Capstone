# %%
# %matplotlib notebook
import numpy as np
import LoadImage
import Whispers
from Node import Node


load_dict = {
    "holland" : 5,
    "downey" : 5,
    "jungkook": 5,
    "kyrogious" : 5,
    "Ramsey": 5
}

test_dict = {
    "test_holland" :2,
    "test_downey" :2,
    "test_jungkook": 2,
    "test_kyrogious" :2,
    "test_ramsey": 2,
    "random_person" : 5
}


filepaths = LoadImage.filenames_from_dict(load_dict)
filepaths += LoadImage.filenames_from_dict(test_dict, folder="test_images")
nodes, adj_matrix = Whispers.generate_network(filepaths)
# print(nodes[:].label)
Node.plot_graph(nodes, adj_matrix)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (<Figure size 640x480 with 1 Axes>, <AxesSubplot:>)
