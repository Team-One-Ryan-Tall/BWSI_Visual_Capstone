# %%
# %matplotlib widget
from camera import take_picture
import LoadImage
import BoundedBox
import Descriptors
from Database import Database
from facenet_models import FacenetModel

# %%
model = FacenetModel()
image = LoadImage.load_image("ryan.png")

BoundedBox.display_boxes(model, "img.png")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
database = Database()
descriptors = Descriptors.descriptors_from_file("ryan.png")
database.add_entry("Ryan", descriptors)

# %%
print(database.identify_face(descriptors))
# Out:
# (512,)
# (512,)
# {1.0: 'Ryan'}
# Ryan
